# %% [markdown]
# Create Function Using Default Arguments

# %%
def reservation_status(passenger_name, ticket_status = "Confirmed"):
    print("Passenger Name:", passenger_name)
    print("Ticket Status:", ticket_status)

reservation_status("Rahul Sharma")
reservation_status("Amit Verma", "Waiting")
# Out:
# Passenger Name: Rahul Sharma
# Ticket Status: Confirmed
# Passenger Name: Amit Verma
# Ticket Status: Waiting

# %% [markdown]
# Use *args (Variable Length Arguments)

# %%
def passenger_booking(*passengers):
    print("Passengers List:")
    for i in passengers:
        print("Passenger name:", i)
passenger_booking("Rahul Sharma", "Priya Singh", "Amit Verma", "Neha Kapoor")
# Out:
# Passengers List:
# Passenger name: Rahul Sharma
# Passenger name: Priya Singh
# Passenger name: Amit Verma
# Passenger name: Neha Kapoor

# %% [markdown]
# Use **kwargs (Keyword Variable Arguments)

# %%
def ticket_details(**details):
   print("Ticket Information:")
   for key, value in details.items():
       print(key, ":", value)

ticket_details(
    passenger_name="Rahul Sharma",
    train_name="Rajdhani Express",
    seat_number="B1-21",
    fare=2500,
    status="Confirmed")
# Out:
# Ticket Information:
# passenger_name : Rahul Sharma
# train_name : Rajdhani Express
# seat_number : B1-21
# fare : 2500
# status : Confirmed

# %% [markdown]
# Create Recursive Seat Countdown Function

# %%
def seat_countdown(seats):
    if seats == 0:
        print("All Seats are booked")
        return
    print("Remaining Seats:", seats)
    seat_countdown(seats - 1)
seat_countdown(5)
# Out:
# Remaining Seats: 5
# Remaining Seats: 4
# Remaining Seats: 3
# Remaining Seats: 2
# Remaining Seats: 1
# All Seats are booked

# %% [markdown]
# Create Recursive Passenger Verification Function

# %%
def verify_passenger(passenger_number):
    if passenger_number == 0:
        print("Verification Completed")
        return
    print("Verifying Passengers:", passenger_number)
    verify_passenger(passenger_number - 1)
verify_passenger(5)
# Out:
# Verifying Passengers: 5
# Verifying Passengers: 4
# Verifying Passengers: 3
# Verifying Passengers: 2
# Verifying Passengers: 1
# Verification Completed

# %% [markdown]
# Build Final Advanced Booking Module

# %%
def final_booking(train_name = "Rajdhani Express", *seat_numbers):
    print("========================================")
    print("========Railway Reservation ============")
    print("========================================")
    print("Train Name:", train_name)
    for seat in seat_numbers:
        print("Allocated Seats", seat)
final_booking("Rajdhani Express",
              "B1-21",
               "B1-22",
                "B1-23" )
# Out:
# ...
# ========Railway Reservation ============
# ...
# Train Name: Rajdhani Express
# Allocated Seats B1-21
# Allocated Seats B1-22
# Allocated Seats B1-23
