# %%
n = 0
fact = 1
for i in range(1, n+1):
    fact = fact * i
print(fact)
# Out:
# 1

# %%
my_list = [1, 2, 3]
my_list.append("IT")
print(my_list)

# %%
li = [1, 2, 3]
a = [1]

li = a.extend(li)
print(a)
# Out:
# [1, 1, 2, 3]

# %%
li = [3, 4 , 6]
print(li[::-1])
# Out:
# [6, 4, 3]
