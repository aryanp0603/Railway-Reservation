# %% [markdown]
# Task 1

# %%
class RailwayReservation:
    def __init__(self, passenger_name, train_name, seat_number):
        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number

ticket1 = RailwayReservation("Rahul Sharma", "Rajdhani Express", "A1-21")
print(ticket1.passenger_name)
print(ticket1.train_name)
print(ticket1.seat_number)
# Out:
# Rahul Sharma
# Rajdhani Express
# A1-21

# %% [markdown]
# Task 2

# %%
class Reservation:

    def __init__(self, passenger_name, seat_number):
        	
        self.passenger_name = passenger_name
        self.seat_number = seat_number
 
    def display_ticket(self):
 
        print("Passenger :", self.passenger_name)
        print("Seat Number :", self.seat_number)
        print("-----------------------------------")
t1 = Reservation("Aryan", "A1-21")
t2 = Reservation("Aditya", "A1-22")
t3 = Reservation("Rohit", "A2-23")

t1.display_ticket()
t2.display_ticket()
t3.display_ticket()
# Out:
# Passenger : Aryan
# Seat Number : A1-21
# -----------------------------------
# Passenger : Aditya
# Seat Number : A1-22
# -----------------------------------
# Passenger : Rohit
# Seat Number : A2-23
# -----------------------------------

# %% [markdown]
# Task 3

# %%
class RailwayReservation:

    def __init__(
        self,
        passenger_name,
        train_name,
        seat_number,
        ticket_price):

        self.passenger_name = passenger_name
        self.train_name = train_name
        self.seat_number = seat_number
        self.ticket_price = ticket_price
        print("Reservation Created Successfully")

    def display_ticket(self):

        print("===================================")
        print(" Railway Reservation Ticket ")
        print("===================================")
        print("Passenger Name :", self.passenger_name)
        print("Train Name :", self.train_name)
        print("Seat Number :", self.seat_number)
        print("Ticket Price :", self.ticket_price)

    def __del__(self):
        print("Reservation Cancelled")

# %%
ticket1 = RailwayReservation(
    "Neha Kapoor",
    "Rajdhani Express",
    "A1-25",
    2450)
# Out:
# Reservation Created Successfully

# %%
ticket1.display_ticket()
# Out:
# ===================================
#  Railway Reservation Ticket
# ===================================
# Passenger Name : Neha Kapoor
# Train Name : Rajdhani Express
# Seat Number : A1-25
# Ticket Price : 2450

# %%
del ticket1
# Out:
# Reservation Cancelled
