# %% [markdown]
# Task 3: Extract Ticket Data Using String Slicing

# %%
ticket_id = "WRB24567"
zone = ticket_id[0:2]
coach = ticket_id[2:4]
ticket_number = ticket_id[4:]
print("Ticket id:", ticket_id)
print("Railway zone:", zone)
print("Coach number:", coach)
print("Ticket number:", ticket_number)
# Out:
# Ticket id: WRB24567
# Railway zone: WR
# Coach number: B2
# Ticket number: 4567

# %% [markdown]
# Task 2: Format Ticket Details Using String Formatting

# %%
passenger_name = "Priya Patel"
train_number = 129651
seat_number = "B2-45"
fare = 1250

print(f"Passenger Name: {passenger_name}")
print(f"Train Number: {train_number}")
print(f"Seat Number: {seat_number}")
print(f"Ticket Fare: {fare}")
# Out:
# Passenger Name: Priya Patel
# Train Number: 129651
# Seat Number: B2-45
# Ticket Fare: 1250

# %% [markdown]
# Task 1: Manipulate Ticket Information Using String Methods

# %%
passenger_name = "  rahul sharma  "
train_name = "Rajdhani Express"
print("Original Passenger Name:", passenger_name)
print("Upper Case:", passenger_name.upper())
print("Formatted Name:", passenger_name.strip().title())
print("Train Name:", train_name.upper())
updated_train_name = train_name.replace("Rajdhani", "Vande Bharat")
print("Updated Train Name:", updated_train_name)
# Out:
# Original Passenger Name:   rahul sharma
# Upper Case:   RAHUL SHARMA
# Formatted Name: Rahul Sharma
# Train Name: RAJDHANI EXPRESS
# Updated Train Name: Vande Bharat Express
