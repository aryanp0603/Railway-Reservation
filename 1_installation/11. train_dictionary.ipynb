# %% [markdown]
# Task 1

# %%
train = {
    "Train Number":12951,
    "Train Name":"Mumbai Rajdhani Express",
    "Source": "Mumbai",
    "Destination": "Delhi",
    "Available seats": 120
}

# %%
print("Train Information:")
print(train)

print("\nTrain Number:", train["Train Number"])
print("Train Name:", train["Train Name"])
print("Source Station:", train["Source"])
print("Destination Station:", train["Destination"])
print("Available Seats:", train["Available seats"])
# Out:
# Train Information:
# {'Train Number': 12951, 'Train Name': 'Mumbai Rajdhani Express', 'Source': 'Mumbai', 'Destination': 'Delhi', 'Available seats': 120}
#
# Train Number: 12951
# Train Name: Mumbai Rajdhani Express
# Source Station: Mumbai
# Destination Station: Delhi
# Available Seats: 120

# %% [markdown]
# Task 2:1

# %%
train = {
    "Train_Number": 12951,
    "Train_Name": "Mumbai Rajdhani Express",
    "Available_Seats": 120
}

# %% [markdown]
# :2

# %%
print(train)
# Out:
# {'Train_Number': 12951, 'Train_Name': 'Mumbai Rajdhani Express', 'Available_Seats': 120}

# %% [markdown]
# :3

# %%
print("Train Name:", train["Train_Name"])
print("Available Seats:", train["Available_Seats"])
# Out:
# Train Name: Mumbai Rajdhani Express
# Available Seats: 120

# %%
a={}
items = int(input("Enter numbers of items:"))
for i in range(items):
    key = input("Enter key:")
    value = input("Enter values:")
    a[key] = value
print(a)
# Out:
# {'name': 'chintu', 'marks': '35%', 'age': '19', 'status': 'pass'}
